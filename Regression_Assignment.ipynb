# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CarPrice_Assignment.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)

# %%
df.drop(['car_ID','CarName','doornumber','enginelocation','carlength','carwidth','carheight'], axis=1, inplace=True)
df
# Out:
#      symboling fueltype aspiration      carbody drivewheel  wheelbase  \
# 0            3      gas        std  convertible        rwd       88.6
# 1            3      gas        std  convertible        rwd       88.6
# 2            1      gas        std    hatchback        rwd       94.5
# 3            2      gas        std        sedan        fwd       99.8
# 4            2      gas        std        sedan        4wd       99.4
# ..         ...      ...        ...          ...        ...        ...
# 200         -1      gas        std        sedan        rwd      109.1
# 201         -1      gas      turbo        sedan        rwd      109.1
# 202         -1      gas        std        sedan        rwd      109.1
# 203         -1   diesel      turbo        sedan        rwd      109.1
# 204         -1      gas      turbo        sedan        rwd      109.1
#
#      curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  \
# ...

# %%
df.drivewheel.unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# carbody              object
# drivewheel           object
# wheelbase           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
categorical_df = df.select_dtypes(['object'])
categorical_df
# Out:
#     fueltype aspiration      carbody drivewheel enginetype cylindernumber  \
# 0        gas        std  convertible        rwd       dohc           four
# 1        gas        std  convertible        rwd       dohc           four
# 2        gas        std    hatchback        rwd       ohcv            six
# 3        gas        std        sedan        fwd        ohc           four
# 4        gas        std        sedan        4wd        ohc           five
# ..       ...        ...          ...        ...        ...            ...
# 200      gas        std        sedan        rwd        ohc           four
# 201      gas      turbo        sedan        rwd        ohc           four
# 202      gas        std        sedan        rwd       ohcv            six
# 203   diesel      turbo        sedan        rwd        ohc            six
# 204      gas      turbo        sedan        rwd        ohc           four
#
#     fuelsystem
# 0         mpfi
# 1         mpfi
# 2         mpfi
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
categorical_df = categorical_df.apply(label.fit_transform)
categorical_df
# Out:
#      fueltype  aspiration  carbody  drivewheel  enginetype  cylindernumber  \
# 0           1           0        0           2           0               2
# 1           1           0        0           2           0               2
# 2           1           0        2           2           5               3
# 3           1           0        3           1           3               2
# 4           1           0        3           0           3               1
# ..        ...         ...      ...         ...         ...             ...
# 200         1           0        3           2           3               2
# 201         1           1        3           2           3               2
# 202         1           0        3           2           5               3
# 203         0           1        3           2           3               3
# 204         1           1        3           2           3               2
#
#      fuelsystem
# 0             5
# 1             5
# ...

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in categorical_df:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(categorical_df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
numerical_df_int = df.select_dtypes(['int64'])
numerical_df_int
# Out:
#      symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0            3        2548         130         111     5000       21
# 1            3        2548         130         111     5000       21
# 2            1        2823         152         154     5000       19
# 3            2        2337         109         102     5500       24
# 4            2        2824         136         115     5500       18
# ..         ...         ...         ...         ...      ...      ...
# 200         -1        2952         141         114     5400       23
# 201         -1        3049         141         160     5300       19
# 202         -1        3012         173         134     5500       18
# 203         -1        3217         145         106     4800       26
# 204         -1        3062         141         114     5400       19
#
#      highwaympg
# 0            27
# 1            27
# 2            26
# 3            30
# 4            22
# ..          ...
# ...

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in numerical_df_int:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(numerical_df_int[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
numerical_df_float = df.select_dtypes(['float64'])
numerical_df_float
# Out:
#      wheelbase  boreratio  stroke  compressionratio    price
# 0         88.6       3.47    2.68               9.0  13495.0
# 1         88.6       3.47    2.68               9.0  16500.0
# 2         94.5       2.68    3.47               9.0  16500.0
# 3         99.8       3.19    3.40              10.0  13950.0
# 4         99.4       3.19    3.40               8.0  17450.0
# ..         ...        ...     ...               ...      ...
# 200      109.1       3.78    3.15               9.5  16845.0
# 201      109.1       3.78    3.15               8.7  19045.0
# 202      109.1       3.58    2.87               8.8  21485.0
# 203      109.1       3.01    3.40              23.0  22470.0
# 204      109.1       3.78    3.15               9.5  22625.0
#
# [205 rows x 5 columns]

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in numerical_df_float:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(numerical_df_float[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
car_data = pd.concat([numerical_df_int,numerical_df_float,categorical_df], ignore_index=False, axis=1)
car_data
# Out:
#      symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0            3        2548         130         111     5000       21
# 1            3        2548         130         111     5000       21
# 2            1        2823         152         154     5000       19
# 3            2        2337         109         102     5500       24
# 4            2        2824         136         115     5500       18
# ..         ...         ...         ...         ...      ...      ...
# 200         -1        2952         141         114     5400       23
# 201         -1        3049         141         160     5300       19
# 202         -1        3012         173         134     5500       18
# 203         -1        3217         145         106     4800       26
# 204         -1        3062         141         114     5400       19
#
#      highwaympg  wheelbase  boreratio  stroke  compressionratio    price  \
# ...

# %%
X = car_data.drop('price', axis=1)
y = car_data['price'].values

# %%
X = X.iloc[:,:].values

# %%
X
# Out:
# array([[ 3.000e+00,  2.548e+03,  1.300e+02, ...,  0.000e+00,  2.000e+00,
#          5.000e+00],
#        [ 3.000e+00,  2.548e+03,  1.300e+02, ...,  0.000e+00,  2.000e+00,
#          5.000e+00],
#        [ 1.000e+00,  2.823e+03,  1.520e+02, ...,  5.000e+00,  3.000e+00,
#          5.000e+00],
#        ...,
#        [-1.000e+00,  3.012e+03,  1.730e+02, ...,  5.000e+00,  3.000e+00,
#          5.000e+00],
#        [-1.000e+00,  3.217e+03,  1.450e+02, ...,  3.000e+00,  3.000e+00,
#          3.000e+00],
#        [-1.000e+00,  3.062e+03,  1.410e+02, ...,  3.000e+00,  2.000e+00,
#          5.000e+00]])

# %%
y
# Out:
# array([13495.   , 16500.   , 16500.   , 13950.   , 17450.   , 15250.   ,
#        17710.   , 18920.   , 23875.   , 17859.167, 16430.   , 16925.   ,
#        20970.   , 21105.   , 24565.   , 30760.   , 41315.   , 36880.   ,
#         5151.   ,  6295.   ,  6575.   ,  5572.   ,  6377.   ,  7957.   ,
#         6229.   ,  6692.   ,  7609.   ,  8558.   ,  8921.   , 12964.   ,
#         6479.   ,  6855.   ,  5399.   ,  6529.   ,  7129.   ,  7295.   ,
#         7295.   ,  7895.   ,  9095.   ,  8845.   , 10295.   , 12945.   ,
#        10345.   ,  6785.   ,  8916.5  ,  8916.5  , 11048.   , 32250.   ,
#        35550.   , 36000.   ,  5195.   ,  6095.   ,  6795.   ,  6695.   ,
#         7395.   , 10945.   , 11845.   , 13645.   , 15645.   ,  8845.   ,
#         8495.   , 10595.   , 10245.   , 10795.   , 11245.   , 18280.   ,
#        18344.   , 25552.   , 28248.   , 28176.   , 31600.   , 34184.   ,
#        35056.   , 40960.   , 45400.   , 16503.   ,  5389.   ,  6189.   ,
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-ff590f401a45> in <module>
# ----> 1 X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
#       2 X_scaled
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
plt.scatter(X_scaled['symboling'], y)

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X_scaled:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(X_scaled[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
sns.distplot(X_scaled['compressionratio'])

# %%
y.shape
# Out:
# (205,)

# %%
X_scaled.shape
# Out:
# (205, 18)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=0)

# %%
X_train = X_train.reshape(-1,1)

# %%
X_train.shape
# Out:
# (2952, 1)

# %%
X_test = X_test.reshape(-1,1)
X_test.shape
# Out:
# (738, 1)

# %%
y_train = y_train.reshape(-1,1)
y_train.shape
# Out:
# (164, 1)

# %%
y_test = y_test.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-230-c2b654095182> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lr = LinearRegression()
# ----> 3 lr.fit(X_train,y_train)
#       4 y_pred = lr.predict(X_test)
#       5 y_pred
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
# ...

# %%
X_test.shape
# Out:
# (41, 18)

# %%
print('Coefficients: \n', lr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [  337.93586735  1765.63183295  2720.2858321   2822.4122113
#    942.25824797 -1485.047227    1085.68772153  1406.35712661
#   -471.85733818  -900.12301249   967.23999401  -283.23188311
#   -208.47097737  -784.75240343   572.72733968   395.92461944
#   -713.8899863   -736.97253209]
# Mean squared error: 15195890.95
# Coefficient of determination: 0.80

# %%
X_test = X_test[:,np.newaxis,2]
X_test
# Out:
# array([[-0.86438255],
#        [ 0.82069959],
#        [ 0.21888454],
#        [-1.58656061],
#        [-0.43107572],
#        [ 0.45961056],
#        [-0.84030995],
#        [-0.84030995],
#        [ 1.30215163],
#        [-0.84030995],
#        [ 0.89291739],
#        [ 1.83174887],
#        [-1.36990719],
#        [ 0.17073933],
#        [-0.88845515],
#        [ 0.45961056],
#        [ 0.12259413],
#        [ 0.21888454],
#        [-0.40700311],
#        [-0.84030995],
#        [-0.40700311],
#        [-0.16627709],
#        [ 0.12259413],
#        [ 0.45961056],
#        [ 1.06142561],
#        [-0.71994694],
#        [-0.69587434],
#        [-0.16627709],
#        [-0.69587434],
#        [-0.71994694],
#        [-0.43107572],
#        [-0.43107572],
#        [ 0.57997357],
#        [-0.11813189],
#        [-0.71994694],
#        [ 1.97618448],
#        [-0.43107572],
#        [-0.14220449],
#        [-0.88845515],
#        [ 4.26308167],
#        [-0.88845515]])

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-224-4dd9d89aae0b> in <module>
# ----> 1 plt.scatter(X_test, y_test,  color='black')
#       2 plt.plot(X_test, y_pred, color='blue', linewidth=3)
#       3
#       4 plt.xticks(())
#       5 plt.yticks(())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8037121443287295

# %%
lr.score(X_train,y_train)
# Out:
# 0.869290795236252

# %%
lr.score(X_test,y_test)
# Out:
# 0.8037121443287295

# %%
X_test
# Out:
# array([[ 1.33508997e-01, -1.25251243e+00, -8.64382552e-01,
#         -9.15570870e-01, -2.62960216e-01,  8.85740275e-01,
#          1.05519283e+00, -9.41654571e-01, -1.10945866e+00,
#         -3.36969687e-01, -2.88348910e-01,  3.28797975e-01,
#         -4.69295318e-01, -7.17206868e-01, -5.89080707e-01,
#         -1.39082791e-02, -1.47475356e-01, -1.12217929e+00],
#        [-1.47645244e+00,  1.14636922e+00,  8.20699586e-01,
#          1.31523660e+00,  1.57366055e-01, -9.53011688e-01,
#         -9.82763709e-01,  9.56109082e-01, -2.21169547e-01,
#          3.02352718e-01, -2.37873693e-01,  3.28797975e-01,
#         -4.69295318e-01,  1.61656151e+00,  1.21333041e+00,
#         -2.86510549e+00,  1.11220997e+00,  8.69567500e-01],
#        [ 9.38489715e-01, -9.35021953e-02,  2.18884537e-01,
#          1.49132694e-01,  7.87855462e-01, -9.53011688e-01,
#         -8.37195385e-01,  1.73697752e-01, -5.17265919e-01,
#          4.62183319e-01, -4.14536952e-01,  3.28797975e-01,
# ...

# %%
plt.scatter(X_sc.iloc[:,0:], y, color = 'blue') 
  
plt.plot(X_test, y_pred, color = 'red') 
plt.title('Linear Regression') 
# plt.xlabel('Temperature') 
# plt.ylabel('Pressure') 
  
plt.show()

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-4dd9d89aae0b> in <module>
# ----> 1 plt.scatter(X_test, y_test,  color='black')
#       2 plt.plot(X_test, y_pred, color='blue', linewidth=3)
#       3
#       4 plt.xticks(())
#       5 plt.yticks(())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
from sklearn.model_selection import cross_val_score
mse = cross_val_score(lr,X,y,scoring='neg_mean_squared_error',cv=5)
mean_mse=np.mean(mse)
print(mean_mse)
# Out:
# -19847477.75468856

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 15829726.477218777

# %%
from sklearn import metrics
print('MAE :', metrics.mean_absolute_error(y_test,y_pred))
print('MSE:', metrics.mean_squared_error(y_test,y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE : 2689.8475080812987
# MSE: 15829726.477218777
# RMSE: 3978.658879222844

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(X_test)
rf_pred
# Out:
# array([36080.47      , 19118.21      ,  8897.65333333, 13027.10666667,
#        26250.095     ,  6451.765     ,  7384.33      ,  7975.42      ,
#        10670.26      ,  8036.595     , 14793.13666667,  7863.37      ,
#        14917.58166667, 10946.90333333, 41921.415     ,  6328.0925    ,
#         5667.49      , 13751.29      ,  8701.07666667, 10159.18      ,
#        10380.52833333, 15505.72      ,  6410.265     ,  5755.57      ,
#         7064.12633333, 36080.47      ,  9534.35      , 17036.13      ,
#         7324.31666667, 16544.35      , 26478.195     ,  6359.18666667,
#         8097.335     , 18935.56      ,  8149.81      , 26595.755     ,
#        11085.46      , 12414.81      ,  6876.51      , 14327.33      ,
#         8492.135     ])

# %%
rf.score(X_train, y_train)
# Out:
# 0.9859312113095617

# %%
rf.score(X_test, y_test)
# Out:
# 0.9566988764998317

# %%
from sklearn import metrics
print('MAE :', metrics.mean_absolute_error(y_test,rf_pred))
print('MSE:', metrics.mean_squared_error(y_test,rf_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,rf_pred)))
# Out:
# MAE : 1332.3145975609755
# MSE: 3418364.7977099274
# RMSE: 1848.8820399662948

# %%
from statistics import mean # List to maintain the different cross-validation scores 
cross_val_scores_ridge = [] 
  
# List to maintain the different values of alpha 
alpha = [] 
  
# Loop to compute the different values of cross-validation scores 
for i in range(1, 9): 
    ridgeModel = Ridge(alpha = i * 0.5) 
    ridgeModel.fit(X_train, y_train) 
    scores = cross_val_score(ridgeModel, X, y, cv = 10) 
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_ridge.append(avg_cross_val_score) 
    alpha.append(i * 0.25) 
  
# Loop to print the different values of cross-validation scores 
for i in range(0, len(alpha)): 
    print(str(alpha[i])+' : '+str(cross_val_scores_ridge[i]))
# Out:
# 0.25 : -2.733279065801071
# 0.5 : -1.9605247619541533
# 0.75 : -1.5984604198510035
# 1.0 : -1.3731948231227853
# 1.25 : -1.2141010283991338
# 1.5 : -1.092940038374608
# 1.75 : -0.9955550089809939
# 2.0 : -0.9138395312476001

# %%
ridgeModelChosen = Ridge(alpha = 4) 
ridgeModelChosen.fit(X_train, y_train) 
  
# Evaluating the Ridge Regression model
print(ridgeModelChosen.score(X_train, y_train)) 
print(ridgeModelChosen.score(X_test, y_test))
# Out:
# 0.866308178569454
# 0.8100748459680539

# %%
cross_val_scores_lasso = [] 
  
# List to maintain the different values of Lambda 
Lambda = [] 
  
# Loop to compute the cross-validation scores 
for i in range(1, 9): 
    lassoModel = Lasso(alpha = i * 0.25, tol = 0.0925) 
    lassoModel.fit(X_train, y_train) 
    scores = cross_val_score(lassoModel, X, y, cv = 10) 
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_lasso.append(avg_cross_val_score) 
    Lambda.append(i * 0.25) 
  
# Loop to print the different values of cross-validation scores 
for i in range(0, len(alpha)): 
    print(str(alpha[i])+' : '+str(cross_val_scores_lasso[i]))
# Out:
# 0.25 : -7.999198202624614
# 0.5 : -7.96878373536695
# 0.75 : -8.25407529563147
# 1.0 : -8.222582446727433
# 1.25 : -8.315149829331345
# 1.5 : -8.284467188180281
# 1.75 : -8.25373172977882
# 2.0 : -8.223408291369182

# %%
lassoModelChosen = Lasso(alpha = 2, tol = 0.0925) 
lassoModelChosen.fit(X_train, y_train) 
  
# Evaluating the Lasso Regression model 
print(lassoModelChosen.score(X_train, y_train)) 
print(lassoModelChosen.score(X_test, y_test))
# Out:
# 0.8235074908628337
# 0.8087001011040121

# %%
lasso_pred = lassoModelChosen.predict(X_test)

# %%
from sklearn import metrics
print('MAE :', metrics.mean_absolute_error(y_test,lasso_pred))
print('MSE:', metrics.mean_squared_error(y_test,lasso_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,lasso_pred)))
# Out:
# MAE : 2675.307342102778
# MSE: 15101983.212721266
# RMSE: 3886.1270196329488

# %%
ridge_pred = ridgeModelChosen.predict(X_test)

# %%
from sklearn import metrics
print('MAE :', metrics.mean_absolute_error(y_test,ridge_pred))
print('MSE:', metrics.mean_squared_error(y_test,ridge_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,ridge_pred)))
# Out:
# MAE : 2590.6219893629905
# MSE: 14993455.325470153
# RMSE: 3872.1383401771886

# %%
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(X_scaled) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y)

# %%
p_pred = lin2.predict(poly.fit_transform(X_scaled))
p_pred
# Out:
# array([14998.9375 , 14998.9375 , 16498.5625 , 13951.125  , 17449.25   ,
#        15250.125  , 17719.15625, 18906.875  , 23873.25   , 17860.15625,
#        16431.4375 , 16926.5    , 20948.40625, 21129.     , 24566.5    ,
#        30751.53125, 41324.8125 , 36882.09375,  5150.9375 ,  6264.25   ,
#         7746.40625,  5573.65625,  6141.     ,  7958.25   ,  6319.4375 ,
#         7018.0625 ,  7018.0625 ,  8559.1875 ,  8920.96875, 12963.84375,
#         6481.90625,  6856.28125,  5400.5625 ,  6934.78125,  6724.78125,
#         7295.78125,  7295.09375,  7801.28125,  9161.84375,  8819.78125,
#        10352.46875, 12945.75   , 10346.21875,  6786.     ,  8949.6875 ,
#         7746.40625, 11048.875  , 33903.25   , 33903.25   , 36003.9375 ,
#         5195.8125 ,  6427.     ,  6479.4375 ,  6682.3125 ,  7396.34375,
#        11399.78125, 11399.78125, 13637.03125, 15645.15625,  9721.0625 ,
#         9387.78125,  9721.0625 ,  9387.78125, 10795.03125, 11211.84375,
# ...

# %%
x = X_scaled[:,np.newaxis,2]

# %%
plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, p_pred, color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Temperature') 
plt.ylabel('Pressure') 
  
plt.show()

# %%
lin2.score(X_poly,y)
# Out:
# 0.9983472047447776

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8037121443287295

# %%
from sklearn.linear_model import GammaRegressor
gm = GammaRegressor()
gm.fit(X_train,y_train)
gm_pred = gm.predict(X_test)
gm_pred
# Out:
# array([ 7340.94864857, 17300.10052944, 12928.87715717,  4742.26174576,
#        10437.38680691, 14613.1028088 ,  6936.98776525,  7426.72592995,
#        18141.06746889,  7698.82209062, 14836.82495374, 26882.22982422,
#        12346.22473936, 12530.72294163,  6667.35975793, 14031.97509298,
#        11052.66413712, 14003.16155452,  9000.17191864,  7525.86863037,
#        11806.1685242 , 15752.92682857, 11438.58253408, 14359.41091459,
#        18265.68533912,  8421.37715097,  7824.26556801, 16585.49493805,
#         8368.49808354,  7493.46418545,  9683.4623154 , 10625.71527837,
#        16910.59128413, 10154.03502608,  7545.60605208, 22878.90728506,
#        11035.84824219, 15214.41526468,  7366.19281639, 34263.68481583,
#         6655.11205498])

# %%
gm.score(X_train,y_train)
# Out:
# 0.8605772084727519

# %%
gm.score(X_test,y_test)
# Out:
# 0.8360693051657924

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
from statistics import mean # List to maintain the different cross-validation scores 
cross_val_scores_gamma = [] 
  
# List to maintain the different values of alpha 
alpha = [] 
  
# Loop to compute the different values of cross-validation scores 
for i in range(1, 19): 
    gammaModel = GammaRegressor(alpha = i * 2.0,) 
    gammaModel.fit(X_train, y_train) 
    scores = cross_val_score(gammaModel, X, y, cv = 10) 
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_gamma.append(avg_cross_val_score) 
    alpha.append(i * 2.0) 
  
# Loop to print the different values of cross-validation scores 
for i in range(0, len(alpha)): 
    print(str(alpha[i])+' : '+str(cross_val_scores_gamma[i]))
# Out:
# C:\Users\Abhinay.Verma\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\Abhinay.Verma\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\Abhinay.Verma\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\Users\Abhinay.Verma\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# C:\Users\Abhinay.Verma\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# ...

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures
# for creating pipeline
from sklearn.pipeline import Pipeline
# creating pipeline and fitting it on data
Input=[('polynomial',PolynomialFeatures(degree=2)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures()),
#                 ('modal', LinearRegression())])

# %%
poly_pred=pipe.predict(X_test)
#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(X_test,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)
#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(X_test,y_test,s=15)
# plt.plot(x,y_pred,color='r',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-03d4bb1c3430> in <module>
#       5 #plotting predictions
#       6 plt.figure(figsize=(10,6))
# ----> 7 plt.scatter(X_test,y_test,s=15)
#       8 # plt.plot(x,y_pred,color='r',label='Linear Regression')
#       9 plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ...

# %% [markdown]
# # Evaluation Results

# %% [markdown]
# #### Ridge is working better than Linear and lasso regression.
# #### Random Forest regreesor is working better due to ensemble technique and more powerful alogorith than Linear, Ridge and Lasso.
